# %%
import pandas as pd
import numpy as np
import pylab as pl
import os 
import sys
import geopandas as gpd
from geopandas import GeoDataFrame
from shapely.geometry import Point
# %matplotlib inline

# %%
#!wget https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-01.csv
# Out:
# --2017-11-20 16:43:06--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-01.csv
# Resolving s3.amazonaws.com... 52.216.128.253
# Connecting to s3.amazonaws.com|52.216.128.253|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1985964692 (1.8G) [application/octet-stream]
# Saving to: “yellow_tripdata_2015-01.csv”
#
# 100%[====================================>] 1,985,964,692 42.5M/s   in 43s
#
# 2017-11-20 16:43:50 (43.7 MB/s) - “yellow_tripdata_2015-01.csv” saved [1985964692/1985964692]

# %%
#!wget https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2015-01.csv
# Out:
# --2017-11-26 19:50:45--  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2015-01.csv
# Resolving s3.amazonaws.com... 52.216.16.91
# Connecting to s3.amazonaws.com|52.216.16.91|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 243307680 (232M) [application/octet-stream]
# Saving to: “green_tripdata_2015-01.csv”
#
# 100%[======================================>] 243,307,680 51.9M/s   in 4.5s
#
# 2017-11-26 19:50:49 (51.8 MB/s) - “green_tripdata_2015-01.csv” saved [243307680/243307680]

# %%
#!wget https://s3.amazonaws.com/nyc-tlc/trip+data/fhv_tripdata_2015-01.csv
# Out:
# --2017-11-20 19:06:05--  https://s3.amazonaws.com/nyc-tlc/trip+data/fhv_tripdata_2015-01.csv
# Resolving s3.amazonaws.com... 52.216.97.237
# Connecting to s3.amazonaws.com|52.216.97.237|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85733063 (82M) [text/csv]
# Saving to: “fhv_tripdata_2015-01.csv”
#
# 100%[======================================>] 85,733,063  46.0M/s   in 1.8s
#
# 2017-11-20 19:06:07 (46.0 MB/s) - “fhv_tripdata_2015-01.csv” saved [85733063/85733063]

# %%
#!wget https://s3.amazonaws.com/nyc-tlc/misc/taxi_zones.zip
# Out:
# --2017-11-26 18:27:20--  https://s3.amazonaws.com/nyc-tlc/misc/taxi_zones.zip
# Resolving s3.amazonaws.com... 52.216.229.133
# Connecting to s3.amazonaws.com|52.216.229.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1025147 (1001K) [application/zip]
# Saving to: “taxi_zones.zip”
#
# 100%[======================================>] 1,025,147   3.38M/s   in 0.3s
#
# 2017-11-26 18:27:21 (3.38 MB/s) - “taxi_zones.zip” saved [1025147/1025147]

# %%
# !mv taxi_zones.zip data

# %%
# !unzip data/taxi_zones.zip -d data
# Out:
# Archive:  data/taxi_zones.zip
#   inflating: data/taxi_zones.prj
#   inflating: data/taxi_zones.dbf
#   inflating: data/taxi_zones.shp
#   inflating: data/taxi_zones.shp.xml
#   inflating: data/taxi_zones.shx
#   inflating: data/taxi_zones.sbn
#   inflating: data/taxi_zones.sbx

# %%
#!mv yellow_tripdata_2015-01.csv data

# %%
#!mv green_tripdata_2015-01.csv data

# %%
#!mv fhv_tripdata_2015-01.csv data

# %%
taxi_data = pd.read_csv("data/yellow_tripdata_2015-01.csv")

# %%
fhv_data = pd.read_csv("data/fhv_tripdata_2015-01.csv")

# %%
green_data = pd.read_csv("data/green_tripdata_2015-01.csv").reset_index()

# %%
taxi_data.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2         1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3         1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4         1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111           1
# 1           3.30        -74.001648        40.724243           1
# 2           1.80        -73.963341        40.802788           1
# 3           0.50        -74.009087        40.713818           1
# 4           3.00        -73.971176        40.762428           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.974785         40.750618             1
# 1                  N         -73.994415         40.759109             1
# 2                  N         -73.951820         40.824413             2
# 3                  N         -74.004326         40.719986             2
# 4                  N         -74.004181         40.742653             2
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0         12.0    1.0      0.5        3.25           0.0
# 1         14.5    0.5      0.5        2.00           0.0
# 2          9.5    0.5      0.5        0.00           0.0
# 3          3.5    0.5      0.5        0.00           0.0
# 4         15.0    0.5      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.3         17.05
# 1                    0.3         17.80
# 2                    0.3         10.80
# 3                    0.3          4.80
# 4                    0.3         16.30

# %%
fhv_data.head()
# Out:
#   Dispatching_base_num          Pickup_date  locationID
# 0               B00013  2015-01-01 00:30:00         NaN
# 1               B00013  2015-01-01 01:22:00         NaN
# 2               B00013  2015-01-01 01:23:00         NaN
# 3               B00013  2015-01-01 01:44:00         NaN
# 4               B00013  2015-01-01 02:00:00         NaN

# %%
columns = green_data.columns[2:]
green_data = green_data.drop(['Payment_type','Trip_type '], axis=1)
green_data.columns = columns
green_data.head()
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         2  2015-01-01 00:34:42   2015-01-01 00:38:34                  N
# 1         2  2015-01-01 00:34:46   2015-01-01 00:47:23                  N
# 2         1  2015-01-01 00:34:44   2015-01-01 00:38:15                  N
# 3         2  2015-01-01 00:34:48   2015-01-01 00:38:08                  N
# 4         2  2015-01-01 00:34:53   2015-01-01 01:09:10                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           1        -73.922592        40.754528         -73.913635
# 1           1        -73.952751        40.677711         -73.981529
# 2           1        -73.843010        40.719055         -73.846581
# 3           1        -73.860825        40.757793         -73.854042
# 4           1        -73.945183        40.783321         -73.989624
#
#    Dropoff_latitude  Passenger_count     ...      Fare_amount  Extra  MTA_tax  \
# 0         40.765522                1     ...              5.0    0.5      0.5
# 1         40.658978                1     ...             12.0    0.5      0.5
# 2         40.711567                1     ...              5.0    0.5      0.5
# 3         40.749821                1     ...              5.0    0.5      0.5
# 4         40.765450                1     ...             24.5    0.5      0.5
#
#    Tip_amount  Tolls_amount  Ehail_fee  improvement_surcharge  Total_amount  \
# 0         0.0           0.0        NaN                    0.3           6.3
# 1         0.0           0.0        NaN                    0.3          13.3
# 2         1.8           0.0        NaN                    0.0           7.8
# 3         0.0           0.0        NaN                    0.3           6.3
# 4         0.0           0.0        NaN                    0.3          25.8
#
#    Payment_type  Trip_type
# 0             2         1.0
# 1             2         1.0
# 2             1         1.0
# 3             2         1.0
# 4             2         1.0
#
# [5 rows x 21 columns]

# %%
def get_times(data):
    x, y = data
    return (x, y)

# %%
taxi_data.tpep_pickup_datetime = pd.to_datetime(taxi_data.tpep_pickup_datetime)
green_data.lpep_pickup_datetime = pd.to_datetime(green_data.lpep_pickup_datetime)

# %%
taxi_data['day'] = taxi_data.tpep_pickup_datetime.dt.day
taxi_data['hour'] = taxi_data.tpep_pickup_datetime.dt.hour
taxi_data['DAY_HOUR'] = taxi_data[['day', 'hour']].apply(get_times, axis=1)

# %%
green_data['day'] = green_data.lpep_pickup_datetime.dt.day
green_data['hour'] = green_data.lpep_pickup_datetime.dt.hour
green_data['DAY_HOUR'] = green_data[['day', 'hour']].apply(get_times, axis=1)

# %%
crs = {'init':'epsg:4326'}

# %%
geometry = [Point(xy) for xy in zip(green_data.Pickup_longitude, green_data.Pickup_latitude)]
green_df = GeoDataFrame(green_data, crs=crs, geometry=geometry)

# %%
geometry = [Point(xy) for xy in zip(taxi_data.pickup_longitude, taxi_data.pickup_latitude)]
yellow_df = GeoDataFrame(taxi_data, crs=crs, geometry=geometry)

# %%
green_df[['VendorID','lpep_pickup_datetime','day', 'hour', 'DAY_HOUR','geometry']]
yellow_df[['VendorID','tpep_pickup_datetime','day', 'hour', 'DAY_HOUR','geometry']]
# Out:
#           VendorID tpep_pickup_datetime  day  hour  DAY_HOUR  \
# 0                2  2015-01-15 19:05:39   15    19  (15, 19)
# 1                1  2015-01-10 20:33:38   10    20  (10, 20)
# 2                1  2015-01-10 20:33:38   10    20  (10, 20)
# 3                1  2015-01-10 20:33:39   10    20  (10, 20)
# 4                1  2015-01-10 20:33:39   10    20  (10, 20)
# 5                1  2015-01-10 20:33:39   10    20  (10, 20)
# 6                1  2015-01-10 20:33:39   10    20  (10, 20)
# 7                1  2015-01-10 20:33:39   10    20  (10, 20)
# 8                1  2015-01-10 20:33:39   10    20  (10, 20)
# 9                1  2015-01-10 20:33:40   10    20  (10, 20)
# 10               1  2015-01-10 20:33:40   10    20  (10, 20)
# 11               1  2015-01-10 20:33:41   10    20  (10, 20)
# 12               1  2015-01-10 20:33:41   10    20  (10, 20)
# 13               1  2015-01-10 20:33:41   10    20  (10, 20)
# 14               1  2015-01-10 20:33:41   10    20  (10, 20)
# 15               2  2015-01-15 19:05:39   15    19  (15, 19)
# 16               2  2015-01-15 19:05:40   15    19  (15, 19)
# 17               2  2015-01-15 19:05:40   15    19  (15, 19)
# 18               2  2015-01-15 19:05:41   15    19  (15, 19)
# 19               2  2015-01-15 19:05:41   15    19  (15, 19)
# 20               2  2015-01-15 19:05:41   15    19  (15, 19)
# 21               2  2015-01-15 19:05:41   15    19  (15, 19)
# 22               2  2015-01-15 19:05:41   15    19  (15, 19)
# 23               2  2015-01-15 19:05:41   15    19  (15, 19)
# 24               2  2015-01-15 19:05:41   15    19  (15, 19)
# 25               2  2015-01-15 19:05:41   15    19  (15, 19)
# 26               2  2015-01-15 19:05:42   15    19  (15, 19)
# 27               2  2015-01-15 19:05:42   15    19  (15, 19)
# 28               2  2015-01-15 19:05:42   15    19  (15, 19)
# 29               2  2015-01-15 19:05:42   15    19  (15, 19)
# ...            ...                  ...  ...   ...       ...
# 12748956         2  2015-01-23 12:27:15   23    12  (23, 12)
# 12748957         2  2015-01-23 12:27:15   23    12  (23, 12)
# 12748958         2  2015-01-23 12:27:15   23    12  (23, 12)
# 12748959         2  2015-01-23 12:27:15   23    12  (23, 12)
# 12748960         2  2015-01-23 12:27:16   23    12  (23, 12)
# 12748961         2  2015-01-23 12:27:16   23    12  (23, 12)
# 12748962         2  2015-01-23 12:27:17   23    12  (23, 12)
# 12748963         2  2015-01-23 12:27:17   23    12  (23, 12)
# 12748964         1  2015-01-10 19:01:40   10    19  (10, 19)
# 12748965         1  2015-01-10 19:01:40   10    19  (10, 19)
# 12748966         1  2015-01-10 19:01:41   10    19  (10, 19)
# 12748967         1  2015-01-10 19:01:41   10    19  (10, 19)
# 12748968         1  2015-01-10 19:01:41   10    19  (10, 19)
# 12748969         1  2015-01-10 19:01:41   10    19  (10, 19)
# 12748970         1  2015-01-10 19:01:41   10    19  (10, 19)
# 12748971         1  2015-01-10 19:01:42   10    19  (10, 19)
# 12748972         1  2015-01-10 19:01:42   10    19  (10, 19)
# 12748973         1  2015-01-10 19:01:42   10    19  (10, 19)
# 12748974         1  2015-01-10 19:01:43   10    19  (10, 19)
# 12748975         1  2015-01-10 19:01:43   10    19  (10, 19)
# 12748976         1  2015-01-10 19:01:43   10    19  (10, 19)
# 12748977         1  2015-01-10 19:01:43   10    19  (10, 19)
# 12748978         1  2015-01-10 19:01:43   10    19  (10, 19)
# 12748979         1  2015-01-10 19:01:43   10    19  (10, 19)
# 12748980         1  2015-01-10 19:01:44   10    19  (10, 19)
# 12748981         1  2015-01-10 19:01:44   10    19  (10, 19)
# 12748982         1  2015-01-10 19:01:44   10    19  (10, 19)
# 12748983         1  2015-01-10 19:01:44   10    19  (10, 19)
# 12748984         1  2015-01-10 19:01:44   10    19  (10, 19)
# 12748985         1  2015-01-10 19:01:45   10    19  (10, 19)
#
#                                               geometry
# 0            POINT (-73.993896484375 40.7501106262207)
# 1          POINT (-74.00164794921875 40.7242431640625)
# 2         POINT (-73.96334075927734 40.80278778076172)
# 3         POINT (-74.00908660888672 40.71381759643555)
# 4         POINT (-73.97117614746094 40.76242828369141)
# 5          POINT (-73.87437438964845 40.7740478515625)
# 6          POINT (-73.9832763671875 40.72600936889648)
# 7          POINT (-74.00266265869139 40.7341423034668)
# 8         POINT (-73.78304290771484 40.64435577392577)
# 9         POINT (-73.98558807373048 40.76794815063477)
# 10        POINT (-73.98861694335938 40.72310256958008)
# 11        POINT (-73.99378204345702 40.75141906738281)
# 12        POINT (-74.00836181640625 40.70437622070313)
# 13        POINT (-73.97394561767578 40.76044845581055)
# 14         POINT (-74.00672149658203 40.7317771911621)
# 15        POINT (-73.97642517089844 40.73981094360352)
# 16        POINT (-73.96870422363281 40.75424575805664)
# 17        POINT (-73.86305999755859 40.76958084106445)
# 18        POINT (-73.94554138183594 40.77942276000977)
# 19         POINT (-73.8744583129883 40.77400970458984)
# 20        POINT (-73.97660064697266 40.75189590454102)
# 21        POINT (-73.99495697021484 40.74507904052734)
# 22        POINT (-74.00093841552734 40.74706268310547)
# 23        POINT (-74.00277709960938 40.71789169311523)
# 24        POINT (-73.99745941162109 40.73636245727539)
# 25        POINT (-73.95227813720702 40.82399368286133)
# 26        POINT (-73.99112701416014 40.75008010864258)
# 27        POINT (-73.78657531738281 40.64412689208984)
# 28        POINT (-73.99366760253906 40.74144744873047)
# 29        POINT (-73.98529052734375 40.74408340454102)
# ...                                                ...
# 12748956   POINT (-73.9584426879883 40.77836227416992)
# 12748957  POINT (-73.98733520507811 40.76840591430664)
# 12748958  POINT (-73.95487213134766 40.76557159423828)
# 12748959  POINT (-73.98065185546875 40.75939559936523)
# 12748960   POINT (-73.99284362792969 40.7338752746582)
# 12748961  POINT (-73.98397064208984 40.74933624267577)
# 12748962  POINT (-73.99083709716798 40.75942611694336)
# 12748963  POINT (-73.98410797119139 40.78014755249024)
# 12748964  POINT (-74.00624847412109 40.74137496948241)
# 12748965  POINT (-73.95000457763672 40.77204895019531)
# 12748966  POINT (-73.95235443115234 40.76977920532227)
# 12748967  POINT (-74.00091552734375 40.76200103759766)
# 12748968    POINT (-73.976318359375 40.76581573486328)
# 12748969  POINT (-73.95638275146483 40.76712417602539)
# 12748970  POINT (-73.98494720458984 40.72808837890625)
# 12748971  POINT (-73.99362182617188 40.72863388061523)
# 12748972  POINT (-73.96421051025391 40.76744079589844)
# 12748973  POINT (-73.97972869873048 40.76384353637695)
# 12748974  POINT (-73.99372863769531 40.75868988037109)
# 12748975  POINT (-73.98904418945312 40.73038864135742)
# 12748976  POINT (-73.98178863525391 40.76533508300781)
# 12748977  POINT (-73.95147705078125 40.78525161743164)
# 12748978   POINT (-73.9844207763672 40.74826049804688)
# 12748979  POINT (-73.99423980712891 40.75080490112305)
# 12748980  POINT (-73.98082733154298 40.74452972412109)
# 12748981  POINT (-73.95198822021484 40.78621673583984)
# 12748982   POINT (-73.9827423095703 40.72818374633789)
# 12748983   POINT (-73.9793243408203 40.74954986572266)
# 12748984  POINT (-73.99956512451173 40.73848342895508)
# 12748985  POINT (-73.96035003662109 40.76639938354492)
#
# [12748986 rows x 6 columns]

# %%
#green_df.rename(columns={'Rename'})

# %%
weather_data = pd.read_csv("data/1106040.csv")
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (14,15,20,23,25,40,84,85,86,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
fhv_sub = fhv_data[fhv_data.locationID.isnull() == False]

# %%
fhv_sub.Pickup_date = pd.to_datetime(fhv_sub.Pickup_date)
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/pandas/core/generic.py:2701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
fhv_sub['day'] = fhv_sub.Pickup_date.dt.day
fhv_sub['hour'] = fhv_sub.Pickup_date.dt.hour
fhv_sub['DAY_HOUR'] = fhv_sub[['day', 'hour']].apply(get_times, axis=1)
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
taxi_zones = gpd.read_file("data/taxi_zones.shp")

# %%
taxi_zones.crs
# Out:
# {u'datum': u'NAD83',
#  u'lat_0': 40.16666666666666,
#  u'lat_1': 40.66666666666666,
#  u'lat_2': 41.03333333333333,
#  u'lon_0': -74,
#  u'no_defs': True,
#  u'proj': u'lcc',
#  u'units': u'us-ft',
#  u'x_0': 300000,
#  u'y_0': 0}

# %%
taxi_zones = taxi_zones.to_crs(epsg=2263)

# %%
green_df =  green_df.to_crs(epsg=2263)

# %%
yellow_df_sub = yellow_df.sample(1000000)

# %%
yellow_df_sub = yellow_df_sub.to_crs(epsg=2263)

# %%
green_df = green_df.rename(columns={'lpep_pickup_datetime': 'Pickup_date'})
yellow_df_sub = yellow_df.rename(columns={'tpep_pickup_datetime': 'Pickup_date'})
green_df = green_df[['VendorID','Pickup_date','day', 'hour', 'DAY_HOUR','geometry']]
yellow_df_sub = yellow_df_sub[['VendorID','Pickup_date','day', 'hour', 'DAY_HOUR','geometry']]

# %%
#green_df[['Dispatching_base_num','lpep_pickup_datetime','day', 'hour', 'DAY_HOUR','geometry']]

# %%
merged_taxis = green_df.append(yellow_df_sub)

# %%
taxi_with_zones = gpd.sjoin(merged_taxis, taxi_zones)

# %%
taxi_with_zones.head()
# Out:
#     VendorID         Pickup_date  day  hour DAY_HOUR  \
# 0          2 2015-01-01 00:34:42    1     0   (1, 0)
# 8          2 2015-01-01 00:35:13    1     0   (1, 0)
# 9          2 2015-01-01 00:35:09    1     0   (1, 0)
# 16         2 2015-01-01 00:35:29    1     0   (1, 0)
# 46         2 2015-01-01 00:35:13    1     0   (1, 0)
#
#                                        geometry  index_right  OBJECTID  \
# 0   POINT (1005696.150913268 214181.0758290828)            6         7
# 8   POINT (1007206.027477717 217957.2073006125)            6         7
# 9   POINT (1006021.928419686 218603.7725072576)            6         7
# 16  POINT (1008950.267569086 219382.0970629308)            6         7
# 46    POINT (1004894.842770228 216894.69798633)            6         7
#
#     Shape_Leng  Shape_Area     zone  LocationID borough
# 0     0.107417     0.00039  Astoria           7  Queens
# 8     0.107417     0.00039  Astoria           7  Queens
# 9     0.107417     0.00039  Astoria           7  Queens
# 16    0.107417     0.00039  Astoria           7  Queens
# 46    0.107417     0.00039  Astoria           7  Queens

# %%
taxi_with_zones['Dispatching_base_num'] = np.nan
taxi_with_zones = taxi_with_zones.rename(columns={'LocationID': 'locationID'})

# %%
taxi_with_zones = taxi_with_zones[['Dispatching_base_num','Pickup_date', 'locationID', 'day', 'hour', 'DAY_HOUR']]

# %%
all_trips = taxi_with_zones.append(fhv_sub)

# %%
all_trips.to_csv("all_trips.csv")

# %%
weather_data.Date = pd.to_datetime(weather_data.DATE)

# %%
weather_subdata = weather_data[weather_data.Date.dt.month == 1]

# %%
weather_subdata.DATE =  pd.to_datetime(weather_subdata.DATE)

# %%
weather_subdata['day'] = weather_subdata.DATE.dt.day
weather_subdata['hour'] = weather_subdata.DATE.dt.hour
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
weather_subdata['DAY_HOUR'] = weather_subdata[['day','hour']].apply(get_times, axis=1)
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
weather_subdata['DAY_HOUR'].head()
# Out:
# 8789    (1, 0)
# 8790    (1, 1)
# 8791    (1, 2)
# 8792    (1, 3)
# 8793    (1, 4)
# Name: DAY_HOUR, dtype: object

# %%
#merged_taxi = taxi_data.merge(weather_subdata, left_on='DAY_HOUR', right_on='DAY_HOUR')
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-18-c60d209d3ce4> in <module>()
# ----> 1 merged_taxi = taxi_data.merge(weather_subdata, left_on='DAY_HOUR', right_on='DAY_HOUR')
#
# NameError: name 'taxi_data' is not defined

# %%
#merged_taxi.shape
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-19-59e432bf1cf8> in <module>()
# ----> 1 merged_taxi.shape
#
# NameError: name 'merged_taxi' is not defined

# %%
weather_subdata.columns
# Out:
# Index([u'STATION', u'STATION_NAME', u'ELEVATION', u'LATITUDE', u'LONGITUDE',
#        u'DATE', u'REPORTTPYE', u'HOURLYSKYCONDITIONS', u'HOURLYVISIBILITY',
#        u'HOURLYPRSENTWEATHERTYPE', u'HOURLYDRYBULBTEMPF',
#        u'HOURLYDRYBULBTEMPC', u'HOURLYWETBULBTEMPF', u'HOURLYWETBULBTEMPC',
#        u'HOURLYDewPointTempF', u'HOURLYDewPointTempC',
#        u'HOURLYRelativeHumidity', u'HOURLYWindSpeed', u'HOURLYWindDirection',
#        u'HOURLYWindGustSpeed', u'HOURLYStationPressure',
#        u'HOURLYPressureTendency', u'HOURLYPressureChange',
#        u'HOURLYSeaLevelPressure', u'HOURLYPrecip', u'HOURLYAltimeterSetting',
#        u'DAILYMaximumDryBulbTemp', u'DAILYMinimumDryBulbTemp',
#        u'DAILYAverageDryBulbTemp', u'DAILYDeptFromNormalAverageTemp',
#        u'DAILYAverageRelativeHumidity', u'DAILYAverageDewPointTemp',
#        u'DAILYAverageWetBulbTemp', u'DAILYHeatingDegreeDays',
#        u'DAILYCoolingDegreeDays', u'DAILYSunrise', u'DAILYSunset',
#        u'DAILYWeather', u'DAILYPrecip', u'DAILYSnowfall', u'DAILYSnowDepth',
#        u'DAILYAverageStationPressure', u'DAILYAverageSeaLevelPressure',
#        u'DAILYAverageWindSpeed', u'DAILYPeakWindSpeed', u'PeakWindDirection',
#        u'DAILYSustainedWindSpeed', u'DAILYSustainedWindDirection',
#        u'MonthlyMaximumTemp', u'MonthlyMinimumTemp', u'MonthlyMeanTemp',
#        u'MonthlyAverageRH', u'MonthlyDewpointTemp', u'MonthlyWetBulbTemp',
#        u'MonthlyAvgHeatingDegreeDays', u'MonthlyAvgCoolingDegreeDays',
#        u'MonthlyStationPressure', u'MonthlySeaLevelPressure',
#        u'MonthlyAverageWindSpeed', u'MonthlyTotalSnowfall',
#        u'MonthlyDeptFromNormalMaximumTemp',
#        u'MonthlyDeptFromNormalMinimumTemp',
#        u'MonthlyDeptFromNormalAverageTemp', u'MonthlyDeptFromNormalPrecip',
#        u'MonthlyTotalLiquidPrecip', u'MonthlyGreatestPrecip',
#        u'MonthlyGreatestPrecipDate', u'MonthlyGreatestSnowfall',
#        u'MonthlyGreatestSnowfallDate', u'MonthlyGreatestSnowDepth',
#        u'MonthlyGreatestSnowDepthDate', u'MonthlyDaysWithGT90Temp',
#        u'MonthlyDaysWithLT32Temp', u'MonthlyDaysWithGT32Temp',
#        u'MonthlyDaysWithLT0Temp', u'MonthlyDaysWithGT001Precip',
#        u'MonthlyDaysWithGT010Precip', u'MonthlyDaysWithGT1Snow',
#        u'MonthlyMaxSeaLevelPressureValue', u'MonthlyMaxSeaLevelPressureDate',
#        u'MonthlyMaxSeaLevelPressureTime', u'MonthlyMinSeaLevelPressureValue',
#        u'MonthlyMinSeaLevelPressureDate', u'MonthlyMinSeaLevelPressureTime',
#        u'MonthlyTotalHeatingDegreeDays', u'MonthlyTotalCoolingDegreeDays',
#        u'MonthlyDeptFromNormalHeatingDD', u'MonthlyDeptFromNormalCoolingDD',
#        u'MonthlyTotalSeasonToDateHeatingDD',
#        u'MonthlyTotalSeasonToDateCoolingDD', u'day', u'hour', u'DAY_HOUR'],
#       dtype='object')

# %%
#merged_taxi[['tpep_pickup_datetime','DATE']].head()
# Out:
#   tpep_pickup_datetime                DATE
# 0  2015-01-15 19:05:39 2015-01-15 19:51:00
# 1  2015-01-15 19:05:39 2015-01-15 19:51:00
# 2  2015-01-15 19:05:40 2015-01-15 19:51:00
# 3  2015-01-15 19:05:40 2015-01-15 19:51:00
# 4  2015-01-15 19:05:41 2015-01-15 19:51:00

# %%
trips_weather = all_trips.merge(weather_subdata, left_on='DAY_HOUR', right_on='DAY_HOUR')

# %%
trips_weather.head()
# Out:
#   Dispatching_base_num         Pickup_date  locationID  day_x  hour_x  \
# 0                  NaN 2015-01-01 00:34:42         7.0      1       0
# 1                  NaN 2015-01-01 00:35:13         7.0      1       0
# 2                  NaN 2015-01-01 00:35:09         7.0      1       0
# 3                  NaN 2015-01-01 00:35:29         7.0      1       0
# 4                  NaN 2015-01-01 00:35:13         7.0      1       0
#
#   DAY_HOUR     STATION                STATION_NAME  ELEVATION  LATITUDE  \
# 0   (1, 0)  WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898
# 1   (1, 0)  WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898
# 2   (1, 0)  WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898
# 3   (1, 0)  WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898
# 4   (1, 0)  WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898
#
#     ...    MonthlyMinSeaLevelPressureDate MonthlyMinSeaLevelPressureTime  \
# 0   ...                             -9999                          -9999
# 1   ...                             -9999                          -9999
# 2   ...                             -9999                          -9999
# 3   ...                             -9999                          -9999
# 4   ...                             -9999                          -9999
#
#   MonthlyTotalHeatingDegreeDays MonthlyTotalCoolingDegreeDays  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#   MonthlyDeptFromNormalHeatingDD MonthlyDeptFromNormalCoolingDD  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    MonthlyTotalSeasonToDateHeatingDD  MonthlyTotalSeasonToDateCoolingDD  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
#
#    day_y  hour_y
# 0      1       0
# 1      1       0
# 2      1       0
# 3      1       0
# 4      1       0
#
# [5 rows x 98 columns]

# %%
trips_weather.to_csv('trips_weather.csv')

# %%
merged_fhv.head(20)
# Out:
#     locationID DAY_HOUR  Dispatching_base_num  Pickup_date  day_x  hour_x  \
# 0          1.0  (1, 15)                     1            1      1       1
# 1          2.0  (1, 15)                     1            1      1       1
# 2          4.0  (1, 15)                    19           19     19      19
# 3          5.0  (1, 15)                     1            1      1       1
# 4          7.0  (1, 15)                    16           16     16      16
# 5         10.0  (1, 15)                     1            1      1       1
# 6         11.0  (1, 15)                     1            1      1       1
# 7         12.0  (1, 15)                     4            4      4       4
# 8         13.0  (1, 15)                    10           10     10      10
# 9         14.0  (1, 15)                     1            1      1       1
# 10        16.0  (1, 15)                     1            1      1       1
# 11        17.0  (1, 15)                    14           14     14      14
# 12        18.0  (1, 15)                     5            5      5       5
# 13        20.0  (1, 15)                     6            6      6       6
# 14        22.0  (1, 15)                     3            3      3       3
# 15        24.0  (1, 15)                     3            3      3       3
# 16        25.0  (1, 15)                     8            8      8       8
# 17        26.0  (1, 15)                     2            2      2       2
# 18        28.0  (1, 15)                     2            2      2       2
# 19        29.0  (1, 15)                     1            1      1       1
#
#        STATION                STATION_NAME  ELEVATION  LATITUDE   ...    \
# 0   WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898   ...
# 1   WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898   ...
# 2   WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898   ...
# 3   WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898   ...
# 4   WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898   ...
# 5   WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898   ...
# 6   WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898   ...
# 7   WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898   ...
# 8   WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898   ...
# 9   WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898   ...
# 10  WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898   ...
# 11  WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898   ...
# 12  WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898   ...
# 13  WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898   ...
# 14  WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898   ...
# 15  WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898   ...
# 16  WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898   ...
# 17  WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898   ...
# 18  WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898   ...
# 19  WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898   ...
#
#     MonthlyMinSeaLevelPressureDate MonthlyMinSeaLevelPressureTime  \
# 0                            -9999                          -9999
# 1                            -9999                          -9999
# 2                            -9999                          -9999
# 3                            -9999                          -9999
# 4                            -9999                          -9999
# 5                            -9999                          -9999
# 6                            -9999                          -9999
# 7                            -9999                          -9999
# 8                            -9999                          -9999
# 9                            -9999                          -9999
# 10                           -9999                          -9999
# 11                           -9999                          -9999
# 12                           -9999                          -9999
# 13                           -9999                          -9999
# 14                           -9999                          -9999
# 15                           -9999                          -9999
# 16                           -9999                          -9999
# 17                           -9999                          -9999
# 18                           -9999                          -9999
# 19                           -9999                          -9999
#
#    MonthlyTotalHeatingDegreeDays MonthlyTotalCoolingDegreeDays  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# 5                            NaN                           NaN
# 6                            NaN                           NaN
# 7                            NaN                           NaN
# 8                            NaN                           NaN
# 9                            NaN                           NaN
# 10                           NaN                           NaN
# 11                           NaN                           NaN
# 12                           NaN                           NaN
# 13                           NaN                           NaN
# 14                           NaN                           NaN
# 15                           NaN                           NaN
# 16                           NaN                           NaN
# 17                           NaN                           NaN
# 18                           NaN                           NaN
# 19                           NaN                           NaN
#
#    MonthlyDeptFromNormalHeatingDD MonthlyDeptFromNormalCoolingDD  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
# 5                             NaN                            NaN
# 6                             NaN                            NaN
# 7                             NaN                            NaN
# 8                             NaN                            NaN
# 9                             NaN                            NaN
# 10                            NaN                            NaN
# 11                            NaN                            NaN
# 12                            NaN                            NaN
# 13                            NaN                            NaN
# 14                            NaN                            NaN
# 15                            NaN                            NaN
# 16                            NaN                            NaN
# 17                            NaN                            NaN
# 18                            NaN                            NaN
# 19                            NaN                            NaN
#
#     MonthlyTotalSeasonToDateHeatingDD  MonthlyTotalSeasonToDateCoolingDD  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
# 5                                 NaN                                NaN
# 6                                 NaN                                NaN
# 7                                 NaN                                NaN
# 8                                 NaN                                NaN
# 9                                 NaN                                NaN
# 10                                NaN                                NaN
# 11                                NaN                                NaN
# 12                                NaN                                NaN
# 13                                NaN                                NaN
# 14                                NaN                                NaN
# 15                                NaN                                NaN
# 16                                NaN                                NaN
# 17                                NaN                                NaN
# 18                                NaN                                NaN
# 19                                NaN                                NaN
#
#     day_y  hour_y
# 0       1      15
# 1       1      15
# 2       1      15
# 3       1      15
# 4       1      15
# 5       1      15
# 6       1      15
# 7       1      15
# 8       1      15
# 9       1      15
# 10      1      15
# 11      1      15
# 12      1      15
# 13      1      15
# 14      1      15
# 15      1      15
# 16      1      15
# 17      1      15
# 18      1      15
# 19      1      15
#
# [20 rows x 98 columns]

# %%
crs = {'init': 'epsg:4326'}

# %%
fhv_sub.locationID = fhv_sub.locationID.astype(int)

# %%
fhv_locs = taxi_zones.merge(fhv_sub, left_on='LocationID', right_on='locationID')

# %%
#fhv_all = fhv_locs.merge(weather_subdata, left_on='DAY_HOUR', right_on='DAY_HOUR')
